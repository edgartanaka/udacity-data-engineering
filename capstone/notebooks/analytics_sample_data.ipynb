# %%
# %load_ext google.cloud.bigquery

# %% [markdown]
# # Viewing samples of data of Analytics tables
# This notebooks contains samples of data of the Analytics tables generated by this Capstone project.
#
# More information on how to visualize Bigquery data from jupyter notebooks: https://cloud.google.com/bigquery/docs/visualize-jupyter

# %% [markdown]
# ## Tables
# - movie
# - person
# - movie_person
# - rating
# - tag
# - genre
# - production_company
# - awards

# %% [markdown]
# # Table analytics.movie
# This table contains all the movies

# %%
# %%bigquery
# SELECT * FROM `edgart-experiments.analytics.movie`
# LIMIT 10
# Out:
#       tconst movie_type         primary_title    original_title start_year  \
# 0  tt0180960      movie  Last Train to Berlin          Rekvijem       1970
# 1  tt0314439      movie                  Nina              Nina       1971
# 2  tt0034649      movie      Det är min musik  Det är min musik       1942
# 3  tt0095712      movie               Nebojsa           Nebojsa       1989
# 4  tt0279900      movie        Kezban Roma'da    Kezban Roma'da       1970
# 5  tt0428661      movie                  Idol              Idol       1984
# 6  tt0184823      movie         The Foundling         Podkidysh       1940
# 7  tt0184071      movie         Zakonnyy brak     Zakonnyy brak       1985
# 8  tt0092651      movie           The Cyclist        Bicycleran       1989
# 9  tt0122770      movie    Valley of the Bees        Údolí vcel       1968
#
#   end_year  runtime_minutes  budget homepage original_language  \
# 0     None             83.0       0                         sr
# ...

# %% [markdown]
# # Table analytics.person
# This table contains all the movies

# %%
# %%bigquery
# SELECT * FROM `edgart-experiments.analytics.person`
# LIMIT 10
# Out:
#       nconst         primary_name  birth_year  death_year  \
# 0  nm0192053      Jeremy Cumpston        1967         NaN
# 1  nm0252775       Judith El Zein        1976         NaN
# 2  nm0480416   Piroska Laczkovich        1906      1982.0
# 3  nm0515272  Margaret Livingston        1895      1984.0
# 4  nm0584080      Anthony Michael        1952      1990.0
# 5  nm0728434         Jovan Ristic        1939      2013.0
# 6  nm0826259      Lionel Steketee        1964         NaN
# 7  nm0841176       Peter Svensson        1974         NaN
# 8  nm0841207        Nils Svenwall        1918      2005.0
# 9  nm0913622          Wendy Wason        1976         NaN
#
#                                 primary_profession  \
# 0                          actor,director,producer
# 1                                   actress,writer
# 2                                 costume_designer
# 3                            actress,miscellaneous
# 4                            actor,director,writer
# ...

# %% [markdown]
# # Table analytics.movie_person
# This table contains all the movies

# %%
# %%bigquery
# SELECT * FROM `edgart-experiments.analytics.movie_person`
# LIMIT 10
# Out:
#        tconst     nconst            movie_primary_title person_primary_name  \
# 0   tt0949770  nm0715381                  The Red Elvis           Dean Reed
# 1   tt7968710  nm1064628                    Dirty Walls               Anouk
# 2   tt0193612  nm0001404                 The Volunteers       Madeline Kahn
# 3   tt6858136  nm0001158       The Starlost: The Return         Keir Dullea
# 4   tt0060868  nm0185568  Purple Death from Outer Space       Buster Crabbe
# 5   tt0321876  nm0399196     The Cycle of Communication      L. Ron Hubbard
# 6   tt7141672  nm0656428       Debra Paget, for Example         Debra Paget
# 7  tt10125574  nm0814506               The Illegal Film        Susan Sontag
# 8  tt11638726  nm0862026                   Sleeping Car       Ingrid Thulin
# 9   tt0963778  nm1083567        My Name Is Albert Ayler        Albert Ayler
#
#    ordering         category   job                  characters
# 0         1  archive_footage  None                        None
# ...

# %% [markdown]
# # Table analytics.rating
# This table contains all the movies

# %%
# %%bigquery
# SELECT * FROM `edgart-experiments.analytics.rating`
# LIMIT 10
# Out:
#       tconst  imdb_rating  imdb_num_votes tmdb_rating  tmdb_num_votes  \
# 0  tt0044557          6.9            5791         6.7              62
# 1  tt0057579          7.2            2081         6.9              30
# 2  tt0073008          5.7            2218         5.6              23
# 3  tt0081568          7.1            8487         7.1              70
# 4  tt0069914          5.8             494         5.8              10
# 5  tt0293271          6.1            3012         5.8              18
# 6  tt0037175          6.1             677         6.8              11
# 7  tt0227669          5.0             118         3.8               7
# 8  tt0093737          5.3            6299         5.5              95
# 9  tt0384428          6.9             218         6.6               7
#
#   ml_rating  ml_num_votes
# 0       3.3          73.0
# 1       3.4          82.0
# 2       2.8          19.0
# 3       3.7         680.0
# 4         2           3.0
# 5      None           NaN
# ...

# %% [markdown]
# # Table analytics.tag

# %%
# %%bigquery
# SELECT * FROM `edgart-experiments.analytics.tag`
# LIMIT 10
# Out:
#       tconst                tag  relevance
# 0  tt0348529           medieval    0.02050
# 1  tt0365125       imdb top 250    0.25450
# 2  tt0071877         true story    0.11375
# 3  tt0089560               kids    0.17100
# 4  tt0029852              1970s    0.30250
# 5  tt0383694          palestine    0.04750
# 6  tt0376541         alcoholism    0.05725
# 7  tt0053716      indiana jones    0.00925
# 8  tt0051516             robots    0.01050
# 9  tt0088979  alternate reality    0.43225

# %% [markdown]
# # Table analytics.genre

# %%
# %%bigquery
# SELECT * FROM `edgart-experiments.analytics.genre`
# LIMIT 10
# Out:
#       tconst      genre
# 0  tt0223958        war
# 1  tt0107316        war
# 2  tt0106364   children
# 3  tt0113533   children
# 4  tt0144164        war
# 5  tt3111626        war
# 6  tt0505917    western
# 7  tt0544322    western
# 8  tt1198675    western
# 9  tt0037318  film-noir

# %% [markdown]
# # Table analytics.production_company

# %%
# %%bigquery
# SELECT * FROM `edgart-experiments.analytics.production_company`
# LIMIT 10
# Out:
#       tconst production_company_name production_company_country
# 0  tt1814890     Cruzical Film&Media                       None
# 1  tt2049542     Cruzical Film&Media                       None
# 2  tt0260688                      2M
# 3  tt1239438                      2M
# 4  tt7148054                      3D
# 5  tt2640244                      3F
# 6  tt2514338                      4L
# 7  tt1002539                      4L
# 8  tt0407021                      4L
# 9  tt0809427                      4L

# %% [markdown]
# # Table analytics.awards

# %%
# %%bigquery
# SELECT * FROM `edgart-experiments.analytics.award`
# LIMIT 10
# Out:
#      award_name  award_year  \
# 0  golden_globe        1944
# 1  golden_globe        1944
# 2  golden_globe        1944
# 3  golden_globe        1944
# 4  golden_globe        1944
# 5  golden_globe        1945
# 6  golden_globe        1945
# 7  golden_globe        1945
# 8  golden_globe        1945
# 9  golden_globe        1945
#
#                                       award_category  award_winner  \
# 0  Best Performance by an Actress in a Supporting...          True
# 1  Best Performance by an Actor in a Supporting R...          True
# 2                          Actress In A Leading Role          True
# 3                     Best Director - Motion Picture          True
# 4                            Actor In A Leading Role          True
# 5                          Actress In A Leading Role          True
# 6                     Best Director - Motion Picture          True
# 7  Best Performance by an Actor in a Supporting R...          True
# ...
