# %% [markdown]
# # Viewing samples of data of analytics tables
# This notebooks contains samples of data of the Analytics tables generated by this Capstone project.
#
# More information on how to visualize Bigquery data from jupyter notebooks: https://cloud.google.com/bigquery/docs/visualize-jupyter

# %%
# %load_ext google.cloud.bigquery
# Out:
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %% [markdown]
# # Table analytics.movie
# This table contains all the movies

# %%
# %%bigquery
# SELECT * FROM `edgart-experiments.analytics.movie`
# LIMIT 10
# Out:
#       tconst                              primary_title  \
# 0  tt0028804                             Double Wedding
# 1  tt0064253                             Downhill Racer
# 2  tt0092561            ...And the Pursuit of Happiness
# 3  tt0060304             2 or 3 Things I Know About Her
# 4  tt0000162                              Niagara Falls
# 5  tt0030522  Olympia Part One: Festival of the Nations
# 6  tt0081144                                    McVicar
# 7  tt0049794                          The Flying Carpet
# 8  tt0023803                     Betty Boop's Penthouse
# 9  tt0092890                              Dirty Dancing
#
#                       original_title start_year end_year  runtime_minutes  \
# 0                     Double Wedding       1937     None               87
# 1                     Downhill Racer       1969     None              101
# 2    ...And the Pursuit of Happiness       1986     None               80
# 3   2 ou 3 choses que je sais d'elle       1967     None               87
# 4                         Les chutes       1897     None                1
# 5  Olympia 1. Teil - Fest der Völker       1938     None              121
# 6                            McVicar       1980     None              112
# 7                  Starik Khottabych       1957     None               86
# 8             Betty Boop's Penthouse       1933     None                7
# 9                      Dirty Dancing       1987     None              100
#
#      budget                                  homepage original_language  \
# 0         0                                                          en
# 1  16500000                                                          en
# 2         0                                                          en
# 3         0                                                          fr
# 4         0                                                          fr
# 5         0                                                          de
# 6         0                                                          en
# 7         0                                                          ru
# 8         0                                                          en
# 9   6000000  http://lionsgateathome.com/dirty-dancing                en
#
#                                             overview  ...  \
# 0  A bohemian free spirit helps meek Waldo win ba...  ...
# 1  An ambitious young skier, determined to break ...  ...
# 2  In 1986, Louis Malle (himself a transplant to ...  ...
# 3  As the city of Paris and the French people gro...  ...
# 4  A stationary camera looks west across Niagara ...  ...
# 5  The First part of Olympia, a documentary about...  ...
# 6  John McVicar was a London Bad Boy. he graduate...  ...
# 7  A boy named Volka discovers an ancient vessel ...  ...
# 8  While Bimbo and Koko admire Betty, their exper...  ...
# 9  Expecting the usual tedium that accompanies a ...  ...
#
#                                 production_companies  \
# 0  [{'id': 21, 'logo_path': '/mjofSXiHpG5t6KYmU4l...
# 1  [{'id': 4, 'logo_path': '/fycMZt242LVjagMByZOL...
# 2  [{'id': 10623, 'logo_path': None, 'name': 'Pre...
# 3  [{'id': 6116, 'logo_path': None, 'name': 'Argo...
# 4  [{'id': 11793, 'logo_path': None, 'name': 'Lum...
# 5  [{'id': 400, 'logo_path': None, 'name': 'Olymp...
# 6  [{'id': 14313, 'logo_path': None, 'name': 'The...
# 7  [{'id': 10845, 'logo_path': '/b8N0K4dvM6CNG9OE...
# 8  [{'id': 8302, 'logo_path': None, 'name': 'Flei...
# 9  [{'id': 137, 'logo_path': None, 'name': 'Great...
#
#                                 production_countries release_date    revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1937-10-15          0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1969-11-06          0
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1986-01-01          0
# 3           [{'iso_3166_1': 'FR', 'name': 'France'}]   1967-03-17          0
# 4           [{'iso_3166_1': 'FR', 'name': 'France'}]   1896-12-25          0
# 5          [{'iso_3166_1': 'DE', 'name': 'Germany'}]   1938-04-20          0
# 6   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   1980-08-01          0
# 7           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1957-12-30          0
# 8  [{'iso_3166_1': 'US', 'name': 'United States o...   1933-03-10          0
# 9  [{'iso_3166_1': 'US', 'name': 'United States o...   1987-08-21  213893795
#
#   runtime                                   spoken_languages    status  \
# 0      87           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1     101  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...  Released
# 2      81           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3      88          [{'iso_639_1': 'fr', 'name': 'Français'}]  Released
# 4       1       [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 5     126           [{'iso_639_1': 'de', 'name': 'Deutsch'}]  Released
# 6     112                                                 []  Released
# 7      86           [{'iso_639_1': 'ru', 'name': 'Pусский'}]  Released
# 8       7           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 9     100           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline vote_average vote_count
# 0                                  A Riot of Laughs!            7         14
# 1  How fast must a man go to get from where he's at?          6.2         36
# 2                                                             7.2         13
# 3                                                             6.6         85
# 4                                                             4.6          8
# 5                                                             7.1         52
# 6  Sentenced to 23 years-and he won't accept one ...          6.9         22
# 7                                                             6.6         27
# 8                                                               7          8
# 9                        Have the time of your life.          7.3       4011
#
# [10 rows x 22 columns]

# %% [markdown]
# # Table analytics.person
# This table contains all the movies

# %%
# %%bigquery
# SELECT * FROM `edgart-experiments.analytics.person`
# LIMIT 10
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0011929    Gisela Aderhold        1975         NaN
# 1  nm0087905    David Blaustein        1953         NaN
# 2  nm0102847       David Bracks        1949         NaN
# 3  nm0206016     Katherine Dawn        1896      1984.0
# 4  nm0265564  Ferdinand Fairfax        1944      2008.0
# 5  nm0381328     Rudolph Herzog        1973         NaN
# 6  nm0793629        Mark Shimer        1972         NaN
# 7  nm0971670   Hiroki Yamaguchi        1978         NaN
# 8  nm1188868         Amy Castle        1990         NaN
# 9  nm1284862        Yoram Sachs        1973         NaN
#
#                     primary_profession  \
# 0                actress,miscellaneous
# 1             producer,director,writer
# 2      actor,stunts,assistant_director
# 3                actress,writer,editor
# 4   director,writer,assistant_director
# 5             producer,writer,director
# 6  visual_effects,animation_department
# 7               director,editor,writer
# 8         actress,soundtrack,executive
# 9                director,writer,actor
#
#                           known_for_titles
# 0  tt0806910,tt0131157,tt8949216,tt0077076
# 1  tt0929426,tt0225210,tt1561315,tt0112648
# 2  tt0080513,tt0088931,tt0090555,tt0079501
# 3  tt0015099,tt0258393,tt0017899,tt0122255
# 4  tt0098833,tt0081963,tt0483603,tt0085994
# 5  tt4665586,tt0438706,tt1213009,tt1794727
# 6  tt0379786,tt1641349,tt2364582,tt0314979
# 7  tt6539340,tt8178604,tt4782186,tt4025150
# 8  tt0273366,tt3229454,tt0118254,tt0192917
# 9            tt4677512,tt3922516,tt0342535

# %% [markdown]
# # Table analytics.movie_person
# This table contains all the movies

# %%
# %%bigquery
# SELECT * FROM `edgart-experiments.analytics.movie_person`
# LIMIT 10
# Out:
#       tconst      nconst  ordering         category  \
# 0  tt0001174   nm0352726         4         director
# 1  tt0010473   nm0532047         4            actor
# 2  tt0023944   nm0894914         8         producer
# 3  tt0027564   nm0394774         6           writer
# 4  tt0032739   nm0838047         6           writer
# 5  tt0035777   nm0491048         1            actor
# 6  tt0040171   nm0005806         8  cinematographer
# 7  tt0066754   nm0006620         1            actor
# 8  tt0072506  nm11443306         7           writer
# 9  tt0081481   nm0135289         8           writer
#
#                          job             characters
# 0                       None                   None
# 1                       None  ["Jonathan Cosgrove"]
# 2                   producer                   None
# 3                 screenplay                   None
# 4  story "Fashions For Sale"                   None
# 5                       None               ["Stan"]
# 6    director of photography                   None
# 7                       None        ["Stef Tassel"]
# 8                    creator                   None
# 9                 screenplay                   None

# %% [markdown]
# # Table analytics.rating
# This table contains all the movies

# %%
# %%bigquery
# SELECT * FROM `edgart-experiments.analytics.rating`
# LIMIT 10
# Out:
#       tconst  imdb_rating  imdb_num_votes tmdb_rating  tmdb_num_votes  \
# 0  tt0044557          6.9            5791         6.7              62
# 1  tt0057579          7.2            2081         6.9              30
# 2  tt0073008          5.7            2218         5.6              23
# 3  tt0081568          7.1            8487         7.1              70
# 4  tt0069914          5.8             494         5.8              10
# 5  tt0293271          6.1            3012         5.8              18
# 6  tt0037175          6.1             677         6.8              11
# 7  tt0227669          5.0             118         3.8               7
# 8  tt0093737          5.3            6299         5.5              95
# 9  tt0384428          6.9             218         6.6               7
#
#   ml_rating  ml_num_votes
# 0       3.3          73.0
# 1       3.4          82.0
# 2       2.8          19.0
# 3       3.7         680.0
# 4         2           3.0
# 5      None           NaN
# 6         3           2.0
# 7      None           NaN
# 8       2.5         195.0
# 9      None           NaN

# %% [markdown]
# # Table analytics.tag

# %%
# %%bigquery
# SELECT * FROM `edgart-experiments.analytics.tag`
# LIMIT 10
# Out:
#       tconst             tag  relevance
# 0  tt0338097     dark comedy    0.03675
# 1  tt0356618       superhero    0.05900
# 2  tt0071877  self discovery    0.18900
# 3  tt0029852         rabbits    0.02375
# 4  tt0062755            beer    0.01550
# 5  tt0062755     unrealistic    0.01700
# 6  tt0078935   san francisco    0.01525
# 7  tt0046874             god    0.05725
# 8  tt0092972       teenagers    0.02125
# 9  tt0103783         gilliam    0.01225

# %% [markdown]
# # Table analytics.genre

# %%
# %%bigquery
# SELECT * FROM `edgart-experiments.analytics.genre`
# LIMIT 10
# Out:
#       tconst      genre
# 0  tt0068786    western
# 1  tt0033987  film-noir
# 2  tt0082193    western
# 3  tt0107144        war
# 4  tt0193164   children
# 5  tt0337711   children
# 6  tt0544342    western
# 7  tt0541911    western
# 8  tt0682652    western
# 9  tt0010676        war

# %% [markdown]
# # Table analytics.production_company

# %%
# %%bigquery
# SELECT * FROM `edgart-experiments.analytics.production_company`
# LIMIT 10
# Out:
#       tconst production_company_name production_company_country
# 0  tt2049542     Cruzical Film&Media                       None
# 1  tt1814890     Cruzical Film&Media                       None
# 2  tt0260688                      2M
# 3  tt1239438                      2M
# 4  tt7148054                      3D
# 5  tt2640244                      3F
# 6  tt0407021                      4L
# 7  tt2514338                      4L
# 8  tt1002539                      4L
# 9  tt0809427                      4L

# %% [markdown]
# # Table analytics.awards

# %%
# %%bigquery
# SELECT * FROM `edgart-experiments.analytics.awards`
# LIMIT 10
# Out:
#    award_year                award_category  award_winner  \
# 0        1928       WRITING (Title Writing)         False
# 1        1928          WRITING (Adaptation)         False
# 2        1928                 ART DIRECTION         False
# 3        1928           OUTSTANDING PICTURE         False
# 4        1928  DIRECTING (Dramatic Picture)         False
# 5        1928                 ART DIRECTION         False
# 6        1929                       ACTRESS         False
# 7        1929                       WRITING         False
# 8        1929                CINEMATOGRAPHY         False
# 9        1929                     DIRECTING         False
#
#                                 film       person_name     tconst     nconst
# 0  The Private Life of Helen of Troy      Gerald Duffy  tt0017979       None
# 1                    The Jazz Singer       Alfred Cohn  tt0018037       None
# 2                         7th Heaven      Harry Oliver  tt0018379       None
# 3                         7th Heaven               Fox  tt0018379       None
# 4                    Sorrell and Son    Herbert Brenon  tt0018429  nm0107543
# 5                            Sunrise     Rochus Gliese  tt0018455       None
# 6                         The Barker     Betty Compson  tt0018674  nm0173993
# 7              Our Dancing Daughters  Josephine Lovett  tt0019237  nm0522674
# 8              Our Dancing Daughters     George Barnes  tt0019237  nm0055604
# 9                        The Patriot    Ernst Lubitsch  tt0019257  nm0523932
